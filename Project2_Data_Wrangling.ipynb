# %% [markdown]
# <a href="https://colab.research.google.com/github/adikaushal-ops/Project_2_Data_Wrangling/blob/main/Project2_Data_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dataset Information**
#
#
# ---
#
#
# Bike sharing systems are new generation of traditional bike rentals where whole process from membership, rental and return back has become automatic.
# Through these systems, user is able to easily rent a bike from a particular position and return back at another positicn. Currently, there are about over 500 bike-
# sharing programs around the world which is composed of over 500 thousands bicycles. Today, there exists great interest in these systems due to their important
# role in traffic, environmental and health issues.
#
# Apart from interesting real world applications of bike sharing systems, the characteristics of data being generated by these systems make them attractive for the
# research. Opposed to other transport services such as bus or subway, the duration of travel, departure and arrval position is explicitly recorded in these
# systems. This feature turns bike sharing system into a virtual sensor network that can be used for sensing mobility in the city. Hence, it is expected that most of
# important events in the city could be detected via monitoring these data.
#
# **Attribute Information:**
#
#
# ---
#
#
# Both hour.csv and day.csv have the following fields, except hr which is not available in day.csv
#
# . instant: record index
# · dteday : date
# . season : season (1:winter, 2:spring, 3:summer, 4:fall)
# · yr : year (0: 2011, 1:2012)
# . mnth : month ( 1 to 12)
# · hr : hour (0 to 23)
# . holiday : weather day is holiday or not (extracted from [Web Link])
# . weekday : day of the week
# . workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# . weathersit :
# . 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# . 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# . 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# . 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# . temp : Normalized temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min =- 8, t_max=+39 (only in hourly scale)
# · atemp: Normalized feeling temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min =- 16, t_max=+50 (only in hourly scale)
# · hum: Normalized humidity. The values are divided to 100 (max)
# · windspeed: Normalized wind speed. The values are divided to 67 (max)
# · casual: count of casual users
# · registered: count of registered users
# . cnt: count of total rental bikes including both casual and registered

# %% [markdown]
# Attribute information:
# ---
# *   Date = date of the ride
# *   Season - 1 = spring, 2 = summer, 3 = fall, 4 = winter
# *   Holiday - whether the day is considered a holiday
# *   Working day - whether the day is neither a weekend nor a holiday
# *   Season - 1 = spring, 2 = summer, 3 = fall, 4 = winter
# ---
# **Weather**:-
#
# 1.   Clear, Few clouds, Partly cloudy, Partly cloudy
# 2.   Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 3.   Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain         +Scattered clouds
# 4.   Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# ---
# *   temp - "feels like" temperature in Celsius
# *   humidity - relative humidity
# *   windspeed - wind speed
# *   casual - number of non-registered user rentals initiated
# *   registered - number of registered user rentals initiated
# *   count - number of total rentals\

# %% [markdown]
#  **Different methods for data wrangling to be used with the help of a business use case:**
#
# ---
# 1. 	Merge datasets - Done
# 2. 	Identify unique values - Done
# 3. 	Drop unnecessary columns - Done
# 4. 	Check the dimensions of the dataset - Done
# 5. 	Check the datatype of the dataset - Done
# 6. 	Check datatype summary - Done
# 7. 	Treat missing values - Done
# 8. 	Validate the correctness of the data at the primary level if applicable - Done

# %% [markdown]
# # **Import Modules**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
pd.options.display.max_columns=999

# %% [markdown]
# # **Loading the Dataset**

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
dataset1=pd.read_csv("/content/drive/MyDrive/d1.csv")
dataset2=pd.read_csv("/content/drive/MyDrive/d2.csv")
dataset3=pd.read_csv('/content/drive/MyDrive/d3.csv')

# %%
df1=dataset1.copy()
df2=dataset2.copy()
df3=dataset3.copy()
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (610, 10)
# (610, 8)
# (390, 16)

# %%
dataset1.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
dataset2.head()
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
dataset2 = dataset2.drop(columns=['Unnamed: 0']) #Already deleted

# %%
dataset2.shape
# Out:
# (610, 7)

# %%
dataset3.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %%
dataset2.head()
# Out:
#    instant   atemp   hum  windspeed  casual  registered  cnt
# 0        1  0.2879  0.81        0.0       3          13   16
# 1        2  0.2727  0.80        0.0       8          32   40
# 2        3  0.2727  0.80        0.0       5          27   32
# 3        4  0.2879  0.75        0.0       3          10   13
# 4        5  0.2879  0.75        0.0       0           1    1

# %%
first_dataset=pd.merge(df1,df2, on='instant')
first_dataset.shape
# Out:
# (610, 17)

# %%
first_dataset.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp  Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24           0  0.2879  0.81        0.0       3          13   16
# 1  0.22           1  0.2727  0.80        0.0       8          32   40
# 2  0.22           2  0.2727  0.80        0.0       5          27   32
# 3  0.24           3  0.2879  0.75        0.0       3          10   13
# 4  0.24           4  0.2879  0.75        0.0       0           1    1

# %%
first_dataset = first_dataset.drop(columns=['Unnamed: 0']) #Already deleted

# %%
first_dataset.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24  0.2879  0.81        0.0       3          13   16
# 1  0.22  0.2727  0.80        0.0       8          32   40
# 2  0.22  0.2727  0.80        0.0       5          27   32
# 3  0.24  0.2879  0.75        0.0       3          10   13
# 4  0.24  0.2879  0.75        0.0       0           1    1

# %%
first_dataset.shape
# Out:
# (610, 16)

# %%
first_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  atemp       599 non-null    float64
#  11  hum         610 non-null    float64
#  12  windspeed   610 non-null    float64
#  13  casual      610 non-null    int64
#  14  registered  610 non-null    int64
#  15  cnt         610 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 72.2+ KB

# %%
first_dataset['atemp'].fillna(first_dataset['atemp'].mean(),inplace=True)

# %%
first_dataset.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
frames=[first_dataset,df3]
data=pd.concat(frames)
data.shape
# Out:
# (1000, 16)

# %%
#Unique Values
data.apply(lambda x:len(x.unique()))
# Out:
# instant       1000
# dteday          45
# season           1
# yr               1
# mnth             2
# hr              24
# holiday          2
# weekday          7
# weathersit       4
# temp            23
# atemp           31
# hum             64
# windspeed       20
# casual          42
# registered     186
# cnt            191
# dtype: int64

# %% [markdown]
# # **Preprocessing Dataset**

# %%
#check for null values
data.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
data = data.rename(columns={'weathersit':'weather',
                            'mnth':'month',
                            'yr':'year',
                            'hr':'hour',
                            'hum':'humidity',
                            'cnt':'count'})
data.head()
# Out:
#    instant      dteday  season  year  month  hour  holiday  weekday  weather  \
# 0        1  01-01-2011       1     0      1     0    False        6        1
# 1        2  01-01-2011       1     0      1     1    False        6        1
# 2        3  01-01-2011       1     0      1     2    False        6        1
# 3        4  01-01-2011       1     0      1     3    False        6        1
# 4        5  01-01-2011       1     0      1     4    False        6        1
#
#    temp   atemp  humidity  windspeed  casual  registered  count
# 0  0.24  0.2879      0.81        0.0       3          13     16
# 1  0.22  0.2727      0.80        0.0       8          32     40
# 2  0.22  0.2727      0.80        0.0       5          27     32
# 3  0.24  0.2879      0.75        0.0       3          10     13
# 4  0.24  0.2879      0.75        0.0       0           1      1

# %%
#data=data.drop(columns=['dteday','year','instant']) #Already Deleted will result in an error if re-run

# %%
data.columns
# Out:
# Index(['season', 'month', 'hour', 'holiday', 'weekday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
#change int columns to category
cols=['season', 'month', 'hour', 'holiday', 'weekday', 'weather']
for col in cols:
  data[col]=data[col].astype('category')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 389
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      1000 non-null   category
#  1   month       1000 non-null   category
#  2   hour        1000 non-null   category
#  3   holiday     1000 non-null   category
#  4   weekday     1000 non-null   category
#  5   weather     1000 non-null   category
#  6   temp        1000 non-null   float64
#  7   atemp       1000 non-null   float64
#  8   humidity    1000 non-null   float64
#  9   windspeed   1000 non-null   float64
#  10  casual      1000 non-null   int64
#  11  registered  1000 non-null   int64
#  12  count       1000 non-null   int64
# dtypes: category(6), float64(4), int64(3)
# memory usage: 70.0 KB

# %%
duplicate_rows = data.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_rows}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
fig,ax=plt.subplots(figsize=(20,10))
sns.pointplot(data=data, x='hour',y='count',ax=ax,hue='weekday')
ax.set(title='Count of Bikes during Weekdays & Weekends')
# Out:
# [Text(0.5, 1.0, 'Count of Bikes during Weekdays & Weekends')]

# %%
fig,ax=plt.subplots(figsize=(20,10))
sns.pointplot(data=data, x='hour',y='casual',ax=ax,hue='weekday')
ax.set(title='Count of Bikes during Weekdays & Weekends: Unregistered Users')
# Out:
# [Text(0.5, 1.0, 'Count of Bikes during Weekdays & Weekends: Unregistered Users')]

# %%
fig,ax=plt.subplots(figsize=(20,10))
sns.pointplot(data=data, x='hour',y='registered',ax=ax,hue='weekday')
ax.set(title='Count of Bikes during Weekdays & Weekends: Registered Users')
# Out:
# [Text(0.5, 1.0, 'Count of Bikes during Weekdays & Weekends: Registered Users')]

# %%
fig,ax=plt.subplots(figsize=(20,10))
sns.pointplot(data=data, x='hour',y='count',ax=ax,hue='holiday')
ax.set(title='Count of Bikes during Holidays')
# Out:
# [Text(0.5, 1.0, 'Count of Bikes during Holidays')]

# %%
fig,ax=plt.subplots(figsize=(20,10))
sns.pointplot(data=data, x='hour',y='count',ax=ax,hue='month')
ax.set(title='Count of Bikes during Months')
# Out:
# [Text(0.5, 1.0, 'Count of Bikes during Months')]

# %%
fig,ax=plt.subplots(figsize=(20,10))
sns.barplot(data=data, x='hour',y='count',ax=ax)
ax.set(title='Count of Bikes during Each Hour')
# Out:
# [Text(0.5, 1.0, 'Count of Bikes during Each Hour')]

# %%
fig,ax=plt.subplots(figsize=(20,10))
sns.barplot(data=data, x='weekday',y='count',ax=ax)
ax.set(title='Count of Bikes during Weekdays')
# Out:
# [Text(0.5, 1.0, 'Count of Bikes during Weekdays')]

# %%
fig,ax=plt.subplots(figsize=(20,10))
sns.barplot(data=data, x='holiday',y='count',ax=ax)
ax.set(title='Count of Bikes during Holidays')
# Out:
# [Text(0.5, 1.0, 'Count of Bikes during Holidays')]

# %%
mt={1:'January',2:'February'}
data['month']=data['month'].replace(mt)
fig,ax=plt.subplots(figsize=(20,10))
sns.barplot(data=data, x='month',y='count',ax=ax)
ax.set(title='Count of Bikes during Months')
# Out:
# [Text(0.5, 1.0, 'Count of Bikes during Months')]

# %%
wd={1:'Clear',2:'Mist',3:'Light Snow',4:'Rain'}
data['weather']=data['weather'].replace(wd)
fig,ax=plt.subplots(figsize=(20,10))
sns.barplot(data=data, x='weather',y='count',ax=ax)
ax.set(title='Count of Bikes during Weathers')
# Out:
# [Text(0.5, 1.0, 'Count of Bikes during Weathers')]

# %%
data['weather'].value_counts()
# Out:
# weather
# Clear         606
# Mist          309
# Light Snow     84
# Rain            1
# Name: count, dtype: int64

# %%
data['month'].value_counts()
# Out:
# month
# January     688
# February    312
# Name: count, dtype: int64

# %%
wd={'Clear':1,'Mist':2,'Light Snow':3,'Rain':4}
data['weather']=data['weather'].replace(wd)

mt={'January':1,'February':2}
data['month']=data['month'].replace(mt)

# %%
data['weather'].value_counts()
# Out:
# weather
# 1    606
# 2    309
# 3     84
# 4      1
# Name: count, dtype: int64

# %%
data['season'].value_counts()
# Out:
# season
# 1    1000
# Name: count, dtype: int64

# %%
fig,(ax1,ax2) = plt.subplots(ncols=2,figsize=(20,6))
sns.regplot(x=data['temp'],y=data['count'],ax=ax1)
ax1.set(title='Relation between Temperature and Users')
sns.regplot(x=data['humidity'],y=data['count'],ax=ax2)
ax2.set(title='Reation between Humidity and Users')
# Out:
# [Text(0.5, 1.0, 'Reation between Humidity and Users')]

# %% [markdown]
# # **Correlation Matrix**

# %%
corr = data.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Finding Outliers

# %%
num_vars=data.select_dtypes(include=['int64','float64']).columns
num_vars
# Out:
# Index(['temp', 'atemp', 'humidity', 'windspeed', 'casual', 'registered',
#        'count'],
#       dtype='object')

# %%
for i in num_vars:
  sns.boxplot(x=data[i])
  plt.xlabel(i)
  plt.show()
